# %%
import pypsa
import pandas as pd
import numpy as np
import yaml
import sys
import os
import yaml

sys.path.append(os.path.abspath("../scripts"))
sys.path.append(os.path.abspath("../pypsa-eur-resilient/config"))
sys.path.append(os.path.abspath("../pypsa-eur-resilient/scripts"))

# %%
from _tools import add_carrier_groups, fill_missing_carriers, update_dict

# %% [markdown]
# ## Params

# %%
# open config yaml
RESULTS = os.path.abspath("../pypsa-eur-resilient/results") + "/"
config_default = yaml.safe_load(open("../pypsa-eur-resilient/config/config.default.yaml", "r"))
config = yaml.safe_load(open("../pypsa-eur-resilient/config/second-run.config.yaml", "r"))
config = update_dict(config_default, config)
grouping = yaml.safe_load(open("../pypsa-eur-resilient/config/grouping.yaml", "r"))
prefix = config["run"]["prefix"]
runs = config["run"]["name"]
columns = config["solve_operations"]["columns"]
planning_horizons = config["scenario"]["planning_horizons"]
clusters = config["scenario"]["clusters"][0]
opts = config["scenario"]["opts"][0]
sector_opts = config["scenario"]["sector_opts"][0]
discount_rate = config["costs"]["fill_values"]["discount rate"]

# %% [markdown]
# ## Import networks

# %%
networks = dict()

for run in runs:
    for planning_horizon in planning_horizons:
        print(f"Loading investment run: {run} {planning_horizon}...")
        n_inv = pypsa.Network(f"{RESULTS}/{prefix}/{run}/networks/base_s_{clusters}_{opts}_{sector_opts}_{planning_horizon}.nc")
        networks[(run, planning_horizon)] = n_inv

        # Fill missing carriers
        fill_missing_carriers(networks[(run, planning_horizon)])

        # # Add carrier groups
        add_carrier_groups(networks[(run, planning_horizon)], grouping)

print("")
# Out:
# Loading investment run: pcipmi 2030...
# INFO:pypsa.io:Imported network base_s_70___2030.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# /home/bobby/projects/pcipmi-policy-targets/workflow/scripts/common.py:35: UserWarning:
#
# Carriers Index(['none', 'unsustainable bioliquids', 'unsustainable biogas',
#        'unsustainable solid biomass', 'rural oil boiler',
#        'urban decentral oil boiler'],
#       dtype='object', name='Carrier') have no technology group
#
# /home/bobby/projects/pcipmi-policy-targets/workflow/scripts/common.py:37: UserWarning:
#
# Carriers Index(['none', 'unsustainable bioliquids', 'unsustainable biogas',
#        'unsustainable solid biomass', 'rural oil boiler',
#        'urban decentral oil boiler'],
#       dtype='object', name='Carrier') have no technology group color
# Loading investment run: pcipmi 2040...
# ...

# %% [markdown]
# ## Costs

# %%
# Create table of CAPEX
capex = pd.DataFrame(
    index=runs,
    columns=planning_horizons,
    dtype=float,
)

for row in runs:
    for planning_horizon in planning_horizons:
        n = networks[(row, planning_horizon)]
        value = n.statistics.capex().sum()
        # get all components
        capex.loc[row, planning_horizon] = value / 1e9 # bn. EUR 

# Create table of OPEX
opex = pd.DataFrame(
    index=runs,
    columns=planning_horizons,
    dtype=float,
)

for row in runs:
    for planning_horizon in planning_horizons:
        n = networks[(row, planning_horizon)]
        value = n.statistics.opex().sum()
        # get all components
        opex.loc[row, planning_horizon] = value / 1e9 # bn. EUR

# TOTEX
totex = capex + opex

# %%
today = 2025
first_year = 2030
end_year = 2060
totex_pv = pd.DataFrame(index=totex.index)

for year in range(first_year, end_year + 1):
    if year in range(first_year, 2040):
        totex_pv[year] = totex[2030] / ((1 + discount_rate) ** (year - today))
    if year in range(2040, 2050):
        totex_pv[year] = totex[2040] / ((1 + discount_rate) ** (year - today))
    if year in range(2050, end_year):
        totex_pv[year] = totex[2050] / ((1 + discount_rate) ** (year - today))

# %%
totex_pv_sum = pd.DataFrame(totex_pv.sum(axis=1), columns=["TOTEX$_{2025}$"])
totex_pv_sum.sort_values(by="TOTEX$_{2025}$", ascending=False, inplace=True)

# %%
totex_pv.T.plot(alpha=0.4, figsize=(10, 7), legend=True)
# Out:
# <Axes: >

# %%
totex_pv_sum
# Out:
#                                          TOTEX$_{2025}$
# no-pipelines                                8413.911058
# pcipmi                                      8408.680124
# pcipmi-delay-10years                        8389.392297
# pcipmi-national-expansion                   8388.386578
# pcipmi-national-international-expansion     8347.552055
# greenfield-pipelines                        8292.683438

# %%
# Sort by TOTEX over lifetime, reindex
capex = capex.loc[totex_pv_sum.index]
opex = opex.loc[totex_pv_sum.index]
totex = totex.loc[totex_pv_sum.index]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(13, 3))

# Define grid layout with width ratios
gs = gridspec.GridSpec(1, 4, width_ratios=[7, 7, 7, 2.5], figure=fig)

# Create axes from the GridSpec
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1], sharey=ax1)
ax3 = fig.add_subplot(gs[2], sharey=ax1)
ax4 = fig.add_subplot(gs[3], sharey=ax1)

for ax in [ax2, ax3, ax4]:
    ax.tick_params(left=False, labelleft=False)

# CAPEX
sns.heatmap(capex, annot=True, cmap="Reds", fmt=".1f", linewidths=0.5,
            cbar_kws={"label": "bn. EUR p.a."}, ax=ax1)
ax1.set_title("CAPEX p.a.")
ax1.set_xlabel("Year")
ax1.set_ylabel("Scenario")

# OPEX
sns.heatmap(opex, annot=True, cmap="Blues", fmt=".1f", linewidths=0.5,
            cbar_kws={"label": "bn. EUR p.a."}, ax=ax2)
ax2.set_title("OPEX p.a. ")
ax2.set_xlabel("Year")
ax2.set_ylabel("")  # Don't repeat "Scenario" if sharing y-axis

sns.heatmap(totex, annot=True, cmap="Purples", fmt=".1f", linewidths=0.5,
            cbar_kws={"label": "bn. EUR p.a."}, ax=ax3)
ax3.set_title("TOTEX p.a.")
ax3.set_xlabel("Year")
ax3.set_ylabel("")  # Don't repeat "Scenario" if sharing y-axis


sns.heatmap(totex_pv_sum, annot=True, cmap="Greys", fmt=".0f", linewidths=0.5,
            cbar_kws={"label": "bn. EUR$_{2025}$"}, ax=ax4)
ax4.set_title("TOTEX")
ax4.set_xlabel("Present value")
ax4.set_ylabel("")  # Don't repeat "Scenario" if sharing y-axis

plt.subplots_adjust(wspace=0.1) 

plt.tight_layout()
# Export
plt.savefig("figures/totex_overview.pdf", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# **Notes on system costs**
# - `no-pipelines` is the cheapest over the assets' lifetime, limit build-out rate of renewables?
# - check DAC, costs, cross compare with carbon networks paper
# - why no pipelines so much cheaper in 2030, should be more expensive
# - co2 pipeline cost check
# - compare with old run

# %% [markdown]
# ### Total system costs by components

# %%
totex_pv_sum.index
# Out:
# Index(['no-pipelines', 'pcipmi', 'pcipmi-delay-10years',
#        'pcipmi-national-expansion', 'pcipmi-national-international-expansion',
#        'greenfield-pipelines'],
#       dtype='object')

# %%
run_order = list(totex_pv_sum.index)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

alpha = 1
region_alpha = 0.8
year = 2030

system_costs = dict()
for planning_horizon in planning_horizons:
    df_system_costs = {}
    for run in runs:
        n = networks[(run, planning_horizon)]
        capex = n.statistics.capex(nice_names=False)
        opex = n.statistics.opex(aggregate_time="sum", nice_names=False)

        costs = capex.add(opex, fill_value=0)
        costs = costs.droplevel(0)[lambda x: x > 0]
        costs = costs.groupby(costs.index).sum()

        key = n.meta["wildcards"]["run"]
        df_system_costs[key] = costs

    df_system_costs = pd.concat(df_system_costs, axis=1)
    df_system_costs.fillna(0, inplace=True)

    # Reorder
    df_system_costs = df_system_costs[run_order]
    system_costs[planning_horizon] = df_system_costs

# %%
grouped_system_costs = dict()
for planning_horizon in planning_horizons:
    grouped_system_costs[planning_horizon] = system_costs[planning_horizon].groupby(grouping["grouping"]).sum()

# %%
run_to_subtract = "no-pipelines"
delta_system_costs = dict()
for planning_horizon in planning_horizons:
    delta_system_costs[planning_horizon] = grouped_system_costs[planning_horizon].sub(grouped_system_costs[planning_horizon][run_to_subtract], axis=0)

# %%
delta_system_costs[2050].div(1e9).round(2)
# Out:
#                                 no-pipelines  pcipmi  pcipmi-delay-10years  \
# carrier
# AC distribution grid                     0.0   -0.54                 -0.49
# AC transmission infrastructure           0.0    0.00                  0.00
# Battery infrastructure                   0.0    0.74                  0.71
# Biomass and biogas                       0.0    2.09                  2.48
# CHP                                      0.0    0.49                  0.45
# CO$_2$                                   0.0   -1.46                 -1.21
# CO$_2$ from process emissions            0.0   -0.00                 -0.00
# CO$_2$ pipeline                          0.0    1.96                  1.96
# CO$_2$ sequestration                     0.0    0.18                  0.11
# Carbon capt. at point sources            0.0    4.34                  4.09
# Coal                                     0.0    0.01                  0.01
# ...

# %%
for planning_horizon in planning_horizons:
    # Stacked bar plot
    norm = 1e9
    unit = "bn. € p.a."
    colors = grouping["group_colors"]

    # fig, ax
    fig, ax = plt.subplots(figsize=(10, 4))

    # Seaborn styling
    sns.set_style("white")
    sns.set_context("paper")
    plt.rcParams['font.family'] = 'sans-serif'

    # Normalize and sort
    plot_df = delta_system_costs[planning_horizon].sort_values(by="pcipmi", ascending=False).div(norm)

    # Transpose for plotting (scenarios on x-axis)
    plot_df_T = plot_df.T
    totals = plot_df_T.sum(axis=0)

    # Separate into positive and negative values
    df_pos = plot_df_T.clip(lower=0)
    df_neg = plot_df_T.clip(upper=0)

    # Plot positive stacks
    bottom_pos = pd.Series(0, index=df_pos.index)
    for carrier in plot_df.index:
        values = df_pos[carrier]
        ax.bar(df_pos.index, values, bottom=bottom_pos, label=carrier, color=colors.get(carrier, None))
        bottom_pos += values

    # Plot negative stacks
    bottom_neg = pd.Series(0, index=df_neg.index)
    for carrier in plot_df.index:
        values = df_neg[carrier]
        ax.bar(df_neg.index, values, bottom=bottom_neg, label=None, color=colors.get(carrier, None))
        bottom_neg += values


    # Add totals on top
    for i, scenario in enumerate(plot_df_T.index):
        total = plot_df_T.loc[scenario].sum()
        # Format the value: add '+' if positive, otherwise show negative sign as usual
        value_text = f"{'+' if total > 0 else ''}{round(total, 1)}" 
        # Add the value text on top of the bar (or wherever you want it positioned)
        if total >= 0:
            ax.text(i,df_pos.loc[scenario].sum(), value_text, ha='center', va='bottom')
            ax.plot([i, i], [df_pos.loc[scenario].sum(), total], color='black', linestyle=':', linewidth=0.5)
        else:
            ax.text(i, df_neg.loc[scenario].sum(), value_text, ha='center', va='top')
            ax.plot([i, i], [df_neg.loc[scenario].sum(), total], color='black', linestyle=':', linewidth=0.5)
        # Add a point for each scenario
        ax.plot(i, total, marker='o', markersize=4, color='black')

    # Axis settings
    total_max = max(bottom_pos.max(), abs(bottom_neg.min()))
    ax.set_ylim(bottom_neg.min()*1.1, bottom_pos.max()*1.1)
    ax.set_xlabel("Scenarios")
    ax.set_ylabel(f"Delta system costs in {unit}")

    # Rotate x-axis labels
    ax.set_xticks(range(len(plot_df_T.index)))
    ax.set_xticklabels(plot_df_T.index, ha='right', rotation=10)

    # Add zero line
    ax.axhline(0, color='black', linewidth=0.8)

    # y axis limits to maximum of positive and negative values of total
    max_abs = max(abs(df_neg.sum(axis=1).min()), df_pos.sum(axis=1).max())
    y_buffer = 10

    ax.set_ylim(-max_abs-y_buffer, max_abs+y_buffer)


    # Legend
    handles, labels = ax.get_legend_handles_labels()
    unique = dict(zip(labels, handles))  # remove duplicates
    ax.legend(unique.values(), unique.keys(), loc='upper center', bbox_to_anchor=(0.5, -0.30),
            frameon=False, labelspacing=0.1, ncol=5)
    plt.setp(ax.get_legend().get_texts(), fontsize='8')
    # title
    ax.set_title(planning_horizon, fontsize=12)

    # # Save
    plt.savefig(f"figures/delta_system_costs_{planning_horizon}.pdf", bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## H2 balance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines

h2_targets = config["pcipmi_policy_paper"]["h2_production_min_mt"]["targets"]


for planning_horizon in planning_horizons:
    # Assuming the relevant imports and data are already available
    df_h2_balance = {}

    # Loop through runs and process the data
    for run in runs:
        n = networks[(run, planning_horizon)]
        balance = n.statistics.energy_balance(bus_carrier="H2", nice_names=False).groupby("carrier").sum()

        key = n.meta["wildcards"]["run"]
        df_h2_balance[key] = balance

    # Concatenate dataframes and fill NaN values with 0
    df_h2_balance = pd.concat(df_h2_balance, axis=1)
    df_h2_balance.fillna(0, inplace=True)

    # Stacked bar plot
    norm = 1e6 * 33.33  # MWh to Mt
    unit = "Mt p.a."

    # Apply Seaborn style
    sns.set_style("white")  # You can choose 'whitegrid', 'darkgrid', 'white', 'dark', or 'ticks'
    sns.set_context("paper")  # Options: 'paper', 'notebook', 'talk', 'poster'
    plt.rcParams['font.family'] = 'sans-serif'

    # Normalize the data
    plot_df = df_h2_balance.div(norm)

    # Create the plot
    fig, ax = plt.subplots(figsize=(10, 4))

    # Plot the stacked bar plot
    plot_df.T.plot.bar(stacked=True, color=grouping["tech_colors"], ax=ax)

    # Plot settings
    ax.set_title("")
    ax.set_xlabel("Scenarios")
    ax.set_ylabel(f"H$_2$ balance in {unit}")

    # Rotate x-axis labels
    ax.set_xticks(range(len(plot_df.columns)))
    ax.set_xticklabels(plot_df.columns)

    # ylim to the max. of abs of all values
    ax.set_ylim(-plot_df.abs().max().max() * 1.2, plot_df.abs().max().max() * 1.2)

    # Legend, reverse order
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles[::-1], labels[::-1], loc='upper center', bbox_to_anchor=(0.5, -0.37), frameon=False, labelspacing=0.1, ncol=5)
    plt.setp(ax.get_legend().get_texts(), fontsize='8')

    # Axis customization
    ax.tick_params(axis='x', rotation=15)
    ax.set_xticklabels(ax.get_xticklabels(), ha="right")

    # Zero line
    ax.axhline(0, color='black', linewidth=0.8)

    # Add line for H2 target
    ax.axhline(h2_targets[planning_horizon], color='black', linestyle=':', linewidth=0.8)

    # Create the H2 target line for the legend
    h2_target_line = mlines.Line2D([0], [0], color='black', linestyle=':', linewidth=0.8)
    h2_target_line.set_label("H$_2$ target")

    # Add the H2 target line to the existing legend
    handles.append(h2_target_line)
    labels.append("H$_2$ target")

    # Update the legend with the new handles and labels
    ax.legend(handles[::-1], labels[::-1], loc='upper center', bbox_to_anchor=(0.5, -0.37), frameon=False, labelspacing=0.1, ncol=5)

    # Add title
    ax.set_title(f"{planning_horizon} H$_2$ balance", fontsize=12)

    # Save the figure
    plt.savefig(f"figures/h2_balance_{planning_horizon}.pdf", bbox_inches='tight')

    # Show the plot
    plt.show()

# %%
df_co2_balance
# Out:
#                                           pcipmi  pcipmi-delay-10years  \
# carrier
# DAC                                 2.279155e+08          2.458704e+08
# Fischer-Tropsch                    -1.312350e+08         -1.314792e+08
# SMR CC                              1.325787e+06          1.024676e+06
# Sabatier                           -7.250770e+00         -8.249460e+00
# co2 sequestered                    -4.000000e+08         -4.000000e+08
# gas for industry CC                 1.052980e+08          1.023005e+08
# methanolisation                    -8.948905e+07         -8.948905e+07
# process emissions CC                1.296885e+08          1.304637e+08
# solid biomass for industry CC       1.546169e+08          1.395810e+08
# urban central CHP CC                6.573080e+00          7.017150e+00
# urban central solid biomass CHP CC  1.879352e+06          1.727856e+06
#
#                                     pcipmi-national-expansion  \
# carrier
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines

co2_seq_targets = config["pcipmi_policy_paper"]["co2_sequestration_min_mt"]["targets"]


for planning_horizon in planning_horizons:
    # Assuming the relevant imports and data are already available
    df_co2_balance = {}

    # Loop through runs and process the data
    for run in runs:
        n = networks[(run, planning_horizon)]
        balance = n.statistics.energy_balance(bus_carrier="co2 stored", nice_names=False).groupby("carrier").sum()

        key = n.meta["wildcards"]["run"]
        df_co2_balance[key] = balance

    # Concatenate dataframes and fill NaN values with 0
    df_co2_balance = pd.concat(df_co2_balance, axis=1)
    df_co2_balance.fillna(0, inplace=True)

    # Stacked bar plot
    norm = 1e6 # Mt to Mt
    unit = "Mt p.a."

    # Apply Seaborn style
    sns.set_style("white")  # You can choose 'whitegrid', 'darkgrid', 'white', 'dark', or 'ticks'
    sns.set_context("paper")  # Options: 'paper', 'notebook', 'talk', 'poster'
    plt.rcParams['font.family'] = 'sans-serif'

    # Normalize the data
    plot_df = df_co2_balance.div(norm)

    # Create the plot
    fig, ax = plt.subplots(figsize=(10, 4))

    # Plot the stacked bar plot
    plot_df.T.plot.bar(stacked=True, color=grouping["tech_colors"], ax=ax)

    # Plot settings
    ax.set_title("")
    ax.set_xlabel("Scenarios")
    ax.set_ylabel(f"CO$_2$ balance in {unit}")

    # Rotate x-axis labels
    ax.set_xticks(range(len(plot_df.columns)))
    ax.set_xticklabels(plot_df.columns)

    # Legend, reverse order
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles[::-1], labels[::-1], loc='upper center', bbox_to_anchor=(0.5, -0.37), frameon=False, labelspacing=0.1, ncol=5)
    plt.setp(ax.get_legend().get_texts(), fontsize='8')

    # Axis customization
    ax.tick_params(axis='x', rotation=15)
    ax.set_xticklabels(ax.get_xticklabels(), ha="right")

    # Zero line
    ax.axhline(0, color='black', linewidth=0.8)

    # Add line for CO2 seq target
    ax.axhline(co2_seq_targets[planning_horizon], color='black', linestyle=':', linewidth=0.8)

    # Create the CO2 seq target line for the legend
    target_line = mlines.Line2D([0], [0], color='black', linestyle=':', linewidth=0.8)
    target_line.set_label("CO$_2$ seq. target")

    # Add the CO2 seq target line to the existing legend
    handles.append(target_line)
    labels.append("CO$_2$ seq. target")

    # Update the legend with the new handles and labels
    ax.legend(handles[::-1], labels[::-1], loc='upper center', bbox_to_anchor=(0.5, -0.37), frameon=False, labelspacing=0.1, ncol=5)

    # Add title
    ax.set_title(f"{planning_horizon} CO$_2$ balance", fontsize=12)

    # Save the figure
    plt.savefig(f"figures/co2_balance_{planning_horizon}.pdf", bbox_inches='tight')

    # Show the plot
    plt.show()
